# %%
import pandas as pd
from textblob import TextBlob

# Sample DataFrame (replace this with loading your actual dataset)
data = {
    'Review Text': [
        "This product is amazing!",
        "Horrible taste, would not buy again.",
        "Good quality, but not worth the price.",
        "Absolutely loved it!"
    ]
}

df = pd.DataFrame(data)

# Function to get sentiment polarity
def get_sentiment(text):
    blob = TextBlob(text)
    return blob.sentiment.polarity  # Returns a value between -1 and 1

# Apply sentiment analysis on the 'Review Text' column
df['Sentiment'] = df['Review Text'].apply(get_sentiment)

# Print results
print(df)
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd

# Sample DataFrame (replace with your actual data)
data = {
    'Review Text': [
        "This product is amazing!",
        "Horrible taste, would not buy again.",
        "Good quality, but not worth the price.",
        "Absolutely loved it!"
    ]
}

df = pd.DataFrame(data)

# Initialize SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# Function to get sentiment score
def get_vader_sentiment(text):
    sentiment_score = sia.polarity_scores(text)
    return sentiment_score['compound']  # Compound score (positive or negative sentiment)

# Apply sentiment analysis on the 'Review Text' column
df['Sentiment'] = df['Review Text'].apply(get_vader_sentiment)

# Print results
print(df)
from transformers import pipeline
import pandas as pd

# Sample DataFrame (replace with your actual data)
data = {
    'Review Text': [
        "This product is amazing!",
        "Horrible taste, would not buy again.",
        "Good quality, but not worth the price.",
        "Absolutely loved it!"
    ]
}

df = pd.DataFrame(data)

# Initialize sentiment-analysis pipeline
classifier = pipeline('sentiment-analysis')

# Function to classify sentiment
def get_transformer_sentiment(text):
    result = classifier(text)
    return result[0]['label']  # 'LABEL_0' or 'LABEL_1'

# Apply sentiment analysis on the 'Review Text' column
df['Sentiment'] = df['Review Text'].apply(get_transformer_sentiment)

# Print results
print(df)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
#                               Review Text  Sentiment
# 0                This product is amazing!      0.750
# 1    Horrible taste, would not buy again.     -1.000
# 2  Good quality, but not worth the price.      0.275
# 3                    Absolutely loved it!      0.875
#                               Review Text  Sentiment
# 0                This product is amazing!     0.6239
# 1    Horrible taste, would not buy again.    -0.5423
# 2  Good quality, but not worth the price.    -0.0127
# 3                    Absolutely loved it!     0.6689
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# ...
